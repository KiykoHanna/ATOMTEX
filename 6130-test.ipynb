# %%
import matplotlib.pyplot as plt
from turtle import color
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# plt.style.use('clasic')

# %%
warm_up = dict()
warm_up['21949-20-120'] = [6.27, 6.37, 6.06, 6.05, 5.90, 5.77, 5.80, 5.76, 6.01, 6.04, 5.90, 5.87, 5.73, 5.71, 5.68, 5.70, 5.72, 5.70, 5.73, 5.67]
warm_up['21949-15min'] = [5.60, 5.51, 5.40, 5.43, 5.73, 5.91, 6.07, 6.22, 6.29, 6.30]
warm_up_m = [6.25, 6.25 + 0.2*6.25, 6.25 - 0.2*6.25]
warm_up_stat = [np.mean(warm_up['21949-20-120']), np.mean(warm_up['21949-15min'])]

# %%
sns.scatterplot(warm_up, palette= 'bright', markers='*')
for i in warm_up_m:
    plt.axhline(y=i)
# Out:
# C:\Users\fitu2\AppData\Local\Temp\ipykernel_6848\1601548947.py:1: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(warm_up, palette= 'bright', markers='*')

# %%
warm_up1 = dict()
warm_up1['21694-20-120'] = [3.87, 5.25, 5.10, 5.01, 4.80, 4.73, 4.67, 4.53, 4.47, 4.43, 4.37, 4.27, 4.24, 4.17, 4.15, 4.08, 4.09, 4.12, 4.13, 4.16, 4.08, 4.09]
warm_up1['21694-15min'] = [4.41, 4.21, 3.91, 4.01, 3.95, 3.74, 3.71, 3.82, 3.93, 4.08]
m = 4.37
warm_up1_m = [m, m + 0.2*m, m - 0.2*m]

# %%
sns.scatterplot(warm_up1, palette= 'bright', markers='*')
for i in warm_up1_m:
    plt.axhline(y=i)
# Out:
# C:\Users\fitu2\AppData\Local\Temp\ipykernel_6848\3742836462.py:1: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(warm_up1, palette= 'bright', markers='*')

# %%
warm_up2 = dict()
warm_up2['21911-20-120'] = [99.5, 96.1, 95.5, 97.4, 92.8, 90.8, 93.6, 94.0, 98.2, 99.8, 101, 100, 99.8, 99.3, 97.9, 97.9, 97.8, 99.4, 99.4, 99.9]
warm_up2['21911-15min'] = [77.6, 80.0, 89.9, 90.8, 96.1, 89.9, 90.1, 87.1, 88.8, 90.5]
m = 95.6
warm_up2_m = [m, m + 0.2*m, m - 0.2*m]

# %%
sns.scatterplot(warm_up2, palette= 'bright', markers='*')
for i in warm_up2_m:
    plt.axhline(y=i)
# Out:
# C:\Users\fitu2\AppData\Local\Temp\ipykernel_6848\3023383035.py:1: UserWarning:
# The markers list has fewer values (1) than needed (2) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(warm_up2, palette= 'bright', markers='*')
