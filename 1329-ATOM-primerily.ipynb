# %% [markdown]
# ### Импортируем библиотеки

# %%
import matplotlib.pyplot as plt
from turtle import color
import pandas as pd
import numpy as np
import seaborn as sns

plt.style.use('dark_background')

# %%
r1 = pd.read_csv('1329-pre.csv')
r1['m_data']
# Out:
#     mass      0      1      2      3      4  activ  aver_coeff  count_av  \
# 0   0.03  1.070  1.020  1.070  0.993  0.980  0.432        0.44      0.19
# 1   0.05  1.140  1.120  1.150  1.110  1.050  0.720        0.39      0.28
# 2   0.07  1.260  1.200  1.180  1.240  1.140  1.008        0.37      0.37
# 3   0.10  1.360  1.330  1.340  1.320  1.360  1.440        0.35      0.51
# 4   0.15  1.450  1.450  1.450  1.490  1.430  2.160        0.29      0.62
# 5   0.20  1.670  1.660  1.720  1.640  1.650  2.880        0.29      0.83
# 6   0.25  1.790  1.830  1.810  1.790  1.840  3.600        0.27      0.98
# 7   0.05  1.080  1.070  1.020  1.000  1.050  0.600        0.35      0.21
# 8   0.10  1.230  1.190  1.150  1.180  1.230  1.200        0.30      0.36
# 9   0.15  1.300  1.360  1.310  1.360  1.370  1.800        0.28      0.51
# 10  0.20  1.380  1.410  1.420  1.360  1.380  2.400        0.23      0.56
# 11  0.35  1.790  1.750  1.780  1.660  1.710  4.200        0.22      0.91
# ...

# %%
sns.pairplot(r1)
