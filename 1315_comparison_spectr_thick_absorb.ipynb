# %% [markdown]
# import libraries

# %%
import os
from turtle import color
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from turtle import color
import seaborn as sns
from sklearn.linear_model import LinearRegression
from pathlib import Path
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %% [markdown]
# # Read the file with database. The file is readen from the githab.

# %%
# read the file with database
url =' https://raw.githubusercontent.com/KiykoHanna/ATOMTEX/main/1315_database.csv'
db = pd.read_csv(url)
db.columns = ['name',
              'nuclid',
              'time',
              'serial_number',
              'geometry',
              'weight',
              'date',
              'sp_beta',
              'Energy',
              'sp_gamma',
              'R_cal',
              'comments'
              ]

# %%
# convert some columns from string to list
def convert_to_list(a_str):
    return [float(i) for i in a_str[1:-1].split(', ')]

list_of_str = ['Energy', 'R_cal', 'sp_gamma', 'sp_beta']
for i in list_of_str:
    db[i] = db[i].apply(convert_to_list)

# %%
db['time'][0]
# Out:
# 10800.0

# %%
# create function for select and show

# function for searching spectrs including a_sytring in the name
def select_spectr(data, a_str, col_name='name'):
    a = data[col_name]
    b = [i if a_str in str(i) else '---' for i in a]
    data = data.loc[data[col_name].isin(b)]
    return data

# function for showing spectrs
def show_comp_spectr(data):
    fig = make_subplots(rows=2, cols=1)
    color_continuous_scale = ["black", "orange", "red", "green", "blue", "purple", 'turquoise', 'violet', 'wheat', 'yellow', 'yellowgreen']
    for j, i in enumerate(data.index):
        y_gamma = data['sp_gamma'][i] / data['time'][i]
        fig.add_trace(
            go.Scatter(x= data['Energy'][i],
                        y= y_gamma,
                        mode="markers",
                        marker=dict(size=3, color= color_continuous_scale[j % len(color_continuous_scale)]),
                        name=data['name'][i] +'gamma'),
            row=1, col=1,

        )

    for j, i in enumerate(data.index):
        y_beta = data['sp_beta'][i] / data['time'][i]
        fig.add_trace(
            go.Scatter(x=data['Energy'][i],
                        y=y_beta,
                        mode="markers",
                        marker=dict(size=3, color= color_continuous_scale[j % len(color_continuous_scale)]),
                        name=data['name'][i] + 'beta'),
            row=2, col=1
        )

    fig.update_layout(height=600, width=1000, title_text="Spectrs")
    fig.show()

# function for normalizing spectrs hight of peak of total absorption

# %%
# select file to show
data = pd.DataFrame()

search = '5174'
col_for_search = 'serial_number'
data = select_spectr(db, search, col_name= col_for_search)

search = 'С'
col_for_search = 'name'
data = select_spectr(data, search, col_name= col_for_search)



print(data.name)
'total number of mathing spectr:', len(data)
# Out:
# 353                           4С0 16437 + 7.5174.5174
# 354                           4С0 16437 + 5.5174.5174
# 355                  4С0 06905 на держателе.5174.5174
# 356                           4С0 06905 + 7.5174.5174
# 357                           4С0 06905 + 5.5174.5174
# 358                            4С0 0661 + 7.5174.5174
# 359                            4С0 0661 + 5.5174.5174
# 366                            3С0 2128 + 7.5174.5174
# 367                                3С0 2127.5174.5174
# 371                            3С0 2127 + 9.5174.5174
# 372                            3С0 2127 + 7.5174.5174
# 373                            3С0 2127 + 5.5174.5174
# 374                           3С0 2127 + 11.5174.5174
# 375                            3С0 2126 + 7.5174.5174
# 420                 1С0 2125-01- №1 и 5   2.5174.5174
# 421          1С0 2125 между насадкой №1 и 5.5174.5174
# 422      1С0 2125 между насадкой №1 и 5   3.5174.5174
# 423     1С0 2125 -05-№1 и 5   3.5174 - копия (2).5174
# 424                1С0 2125 -05- №1 и 5   2.5174.5174
# 425    1С0 2125 -02- №1 и 5   3.5174 - копия (4).5174
# 426                1С0 2125 -02- №1 и 5   2.5174.5174
# 427     1С0 2125 -01-№1 и 5   3.5174 - копия (3).5174
# 428                1С0 2125 -01- №1 и 5   2.5174.5174
# 429       1С0 2125 -003- №1 и 5   3.5174 - копия.5174
# 430               1С0 2125 -003- №1 и 5   2.5174.5174
# 431                            1С0 2125 + 7.5174.5174
# 432                            1С0 2124 + 7.5174.5174
# Name: name, dtype: object
# ('total number of mathing spectr:', 27)

# %%
n_spectr = [371, 372, 373, 374]

data_aa = db.iloc[n_spectr]
show_comp_spectr(data_aa)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="99254fa2-47a6-44c3-8cd8-2d303047d0d7" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("99254fa2-47a6-44c3-8cd8-2d303047d0d7")) {                    Plotly.newPlot(                        "99254fa2-47a6-44c3-8cd8-2d303047d0d7",                        [{"marker":{"color":"black","size":3},"mode":"markers","name":"3\u04210 2127 + 9.5174.5174gamma","x":[0.0,0.0,0.0,3.0,6.0,9.0,12.0,15.1,18.1,21.1,24.1,27.1,30.1,33.200001,36.200001,39.200001,42.200001,45.200001,48.200001,51.299999,54.299999,57.299999,60.299999,63.299999,66.300003,69.300003,72.400002,75.400002,78.400002,81.400002,84.400002,87.400002,90.5,93.5,96.5,99.5,102.5,105.5,108.5,111.599998,114.599998,117.599998,120.599998,123.599998,126.599998,129.699997,132.699997,135.699997,138.699997,141.699997,144.699997,147.699997,150.800003,153.800003,156.800003,159.800003,162.800003,165.800003,168.899994,171.899994,174.899994,177.899994,180.899994,183.899994,187.0,190.0,193.0,196.0,199.0,202.0,205.0,208.100006,211.100006,214.100006,217.100006,220.100006,223.100006,226.199997,229.199997,232.199997,235.199997,238.199997,241.199997,244.199997,247.300003,250.300003,253.300003,256.299988,259.299988,262.299988,265.399994,268.399994,271.399994,274.399994,277.399994,280.399994,283.399994,286.5,289.5,292.5,295.5,298.5,301.5,304.600006,307.600006,310.600006,313.600006,316.600006,319.600006,322.600006,325.700012,328.700012,331.700012,334.700012,337.700012,340.700012,343.799988,346.799988,349.799988,352.799988,355.799988,358.799988,361.899994,364.899994,367.899994,370.899994,373.899994,376.899994,379.899994,383.0,386.0,389.0,392.0,395.0,398.0,401.100006,404.100006,407.100006,410.100006,413.100006,416.100006,419.100006,422.200012,425.200012,428.200012,431.200012,434.200012,437.200012,440.299988,443.299988,446.299988,449.299988,452.299988,455.299988,458.299988,461.399994,464.399994,467.399994,470.399994,473.399994,476.399994,479.5,482.5,485.5,488.5,491.5,494.5,497.600006,500.600006,503.600006,506.600006,509.600006,512.599976,515.599976,518.700012,521.700012,524.700012,527.700012,530.700012,533.700012,536.799988,539.799988,542.799988,545.799988,548.799988,551.799988,554.799988,557.900024,560.900024,563.900024,566.900024,569.900024,572.900024,576.0,579.0,582.0,585.0,588.0,591.0,594.0,597.099976,600.099976,603.099976,606.099976,609.099976,612.099976,615.200012,618.200012,621.200012,624.200012,627.200012,630.200012,633.299988,636.299988,639.299988,642.299988,645.299988,648.299988,651.299988,654.400024,657.400024,660.400024,663.400024,666.400024,669.400024,672.5,675.5,678.5,681.5,684.5,687.5,690.5,693.599976,696.599976,699.599976,702.599976,705.599976,708.599976,711.700012,714.700012,717.700012,720.700012,723.700012,726.700012,729.700012,732.799988,735.799988,738.799988,741.799988,744.799988,747.799988,750.900024,753.900024,756.900024,759.900024,762.900024,765.900024,769.0,772.0,775.0,778.0,781.0,784.0,787.0,790.099976,793.099976,796.099976,799.099976,802.099976,805.099976,808.200012,811.200012,814.200012,817.200012,820.200012,823.200012,826.200012,829.299988,832.299988,835.299988,838.299988,841.299988,844.299988,847.400024,850.400024,853.400024,856.400024,859.400024,862.400024,865.400024,868.5,871.5,874.5,877.5,880.5,883.5,886.599976,889.599976,892.599976,895.599976,898.599976,901.599976,904.700012,907.700012,910.700012,913.700012,916.700012,919.700012,922.700012,925.799988,928.799988,931.799988,934.799988,937.799988,940.799988,943.900024,946.900024,949.900024,952.900024,955.900024,958.900024,961.900024,965.0,968.0,971.0,974.0,977.0,980.0,983.099976,986.099976,989.099976,992.099976,995.099976,998.099976,1001.099976,1004.200012,1007.200012,1010.200012,1013.200012,1016.200012,1019.200012,1022.29 ...
