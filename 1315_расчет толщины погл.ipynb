# %% [markdown]
# <a href="https://colab.research.google.com/github/KiykoHanna/ATOMTEX/blob/main/1315_%D1%80%D0%B0%D1%81%D1%87%D0%B5%D1%82%20%D1%82%D0%BE%D0%BB%D1%89%D0%B8%D0%BD%D1%8B%20%D0%BF%D0%BE%D0%B3%D0%BB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from turtle import color
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

plt.style.use('dark_background')
a = [3.9, 4.0, 4.5, 4.8, 6.7,]
b = [13, 11, 9, 7, 5]

# %%
plt.plot(b, a)

plt.ylabel('скорость счета, имп/с')
plt.xlabel('толщина поглотителя, мм')
plt.title(" ")
plt.grid(alpha=0.2)
plt.legend()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
