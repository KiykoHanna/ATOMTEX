# %% [markdown]
# # Definition of detection limit
# in order to define detection limit the following formula applies:
#
# A = 1.65 * 2 * C/W * sqrt(M * (1/t0 + 1/tb))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
t_0 = 3600
t_b = 10800

# %%
data = pd.DataFrame(columns=['geometry', 'nuclid', 'bg_count_rate', 'C', 'weight'])
data['geometry'] = ['M-1l', 'M-1l', 'M-1l', 'M-1l', 'M-1l', 'M-1l', 'M-05l', 'M-05l', 'M-05l', 'Fl-05l', 'Fl-05l', 'Fl-05l', 'Fl-05l','Fl-01l', 'Fl-01l',  'Fl-01l', 'Fl-01l']
data['nuclid'] = ['I-131', 'Cs-134', 'Cs-137', 'K-40', 'Ra-226', 'Th232', 'Cs-134', 'Cs-137', 'K-40','I-131', 'Cs-134', 'Cs-137', 'K-40', 'I-131', 'Cs-134', 'Cs-137', 'K-40']
data['bg_count_rate'] = [6, 1.5, 2, 1.2, 0.3, 0.15, 1.5, 2, 1.2, 6, 1.5, 2, 1.2, 6, 1.5, 2, 1.2]
data['C'] = [528, 243, 220, 14.5, 54.5, 46, 148, 159, 9.3, 163, 75, 68, 4.54, 67, 31, 28, 1.72]
data['weight'] = [1, 1, 1, 1, 1, 1, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.1, 0.1, 0.1, 0.1]
data['C'] = data['C'] * 0.0001
data['A'] = np.round(1.65 * 2 * 1/data['C'] * np.sqrt(data['bg_count_rate'] * (1/t_0) + (1/t_b)))
data
# Out:
#    geometry  nuclid  bg_count_rate         C  weight      A
# 0      M-1l   I-131           6.00  0.052800     1.0    3.0
# 1      M-1l  Cs-134           1.50  0.024300     1.0    3.0
# 2      M-1l  Cs-137           2.00  0.022000     1.0    4.0
# 3      M-1l    K-40           1.20  0.001450     1.0   47.0
# 4      M-1l  Ra-226           0.30  0.005450     1.0    8.0
# 5      M-1l   Th232           0.15  0.004600     1.0    8.0
# 6     M-05l  Cs-134           1.50  0.014800     0.5    5.0
# 7     M-05l  Cs-137           2.00  0.015900     0.5    5.0
# 8     M-05l    K-40           1.20  0.000930     0.5   73.0
# 9    Fl-05l   I-131           6.00  0.016300     0.5    8.0
# 10   Fl-05l  Cs-134           1.50  0.007500     0.5   10.0
# 11   Fl-05l  Cs-137           2.00  0.006800     0.5   12.0
# 12   Fl-05l    K-40           1.20  0.000454     0.5  150.0
# 13   Fl-01l   I-131           6.00  0.006700     0.1   21.0
# 14   Fl-01l  Cs-134           1.50  0.003100     0.1   24.0
# ...

# %%
detection_limit =  data[['geometry', 'nuclid', 'A']]
dl = pd.pivot_table(detection_limit,
                    index='geometry',
                    columns='nuclid',
                    values='A'
                    )
dl
# Out:
# nuclid    Cs-134  Cs-137  I-131   K-40  Ra-226  Th232
# geometry
# Fl-01l      24.0    30.0   21.0  396.0     NaN    NaN
# Fl-05l      10.0    12.0    8.0  150.0     NaN    NaN
# M-05l        5.0     5.0    NaN   73.0     NaN    NaN
# M-1l         3.0     4.0    3.0   47.0     8.0    8.0

# %% [markdown]
# Coefficient of variation

# %%
n = np.array([46.5, 52.3, 51.8, 52, 55.5, 52.1, 51.2, 48.6, 52.4, 48.2, 55.7, 46.6, 53.8, 54.9, 51.5, 50.8,45.4, 54.0, 54.6, 47.9])
m = np.mean(n)
coef_varr = np.sqrt(np.sum((n-m)**2)/19) / m
coef_varr
# Out:
# 0.06111348782095227

# %% [markdown]
# Overload characteristic

# %%
sd = np.array([13.3, 22.9, 33.5, 44.2])

fig = px.line(sd)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
