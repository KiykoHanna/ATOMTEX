# %% [markdown]
# import libraries

# %%
import os
from turtle import color
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from turtle import color
import seaborn as sns
from sklearn.linear_model import LinearRegression
from pathlib import Path
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %%
# read the file with database
url =' https://raw.githubusercontent.com/KiykoHanna/ATOMTEX/main/1315_database.csv'
db = pd.read_csv(url)
db.columns = ['name',
              'nuclid',
              'time',
              'serial_number',
              'geometry',
              'weight',
              'date',
              'sp_beta',
              'Energy',
              'sp_gamma',
              'R_cal',
              'comments'
              ]

# %%
# convert some columns from string to list
def convert_to_list(a_str):
    return [float(i) for i in a_str[1:-1].split(', ')]

list_of_str = ['Energy', 'R_cal', 'sp_gamma', 'sp_beta']
for i in list_of_str:
    db[i] = db[i].apply(convert_to_list)

# %%
# create function for select and show

# function for searching spectrs including a_sytring in the name
def select_name(data, a_str, col_name='name'):
    a = data[col_name]
    b = [i if a_str in i else '---' for i in a]
    data = data.loc[data[col_name].isin(b)]
    return data

# function for showing spectrs
def show_comp_spectr(data):
    fig = make_subplots(rows=2, cols=1)
    color_continuous_scale = ["black", "orange", "red", "green", "blue", "purple", 'turquoise', 'violet', 'wheat', 'yellow', 'yellowgreen']
    for j, i in enumerate(data.index):
        fig.add_trace(
            go.Scatter(x=data['Energy'][i],
                        y=data['sp_gamma'][i],
                        mode="markers",
                        marker=dict(size=3, color= color_continuous_scale[j % len(color_continuous_scale)]),
                        name=data['name'][i] +'gamma'),
            row=1, col=1,

        )

    for j, i in enumerate(data.index):
        fig.add_trace(
            go.Scatter(x=data['Energy'][i],
                        y=data['sp_beta'][i],
                        mode="markers",
                        marker=dict(size=3, color= color_continuous_scale[j % len(color_continuous_scale)]),
                        name=data['name'][i] + 'beta'),
            row=2, col=1
        )

    fig.update_layout(height=600, width=800, title_text="Spectrs")
    fig.show()

# %%
# select file to show

search = 'Мар Г3 10-2.5175'

data = select_name(db, search, col_name='name')
print(data.name)
len(data)
# Out:
# 45    Мар Г3 10-2.5175
# Name: name, dtype: object
# 1

# %%
show_comp_spectr(data)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a702834d-14c9-4fcb-87c4-b0c1d09692ae" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a702834d-14c9-4fcb-87c4-b0c1d09692ae")) {                    Plotly.newPlot(                        "a702834d-14c9-4fcb-87c4-b0c1d09692ae",                        [{"marker":{"color":"black","size":3},"mode":"markers","name":"\u041c\u0430\u0440 \u04133 10-2.5175gamma","x":[0.0,0.0,0.0,1.7,4.8,7.8,10.9,13.9,17.0,20.0,23.1,26.1,29.1,32.200001,35.200001,38.299999,41.299999,44.400002,47.400002,50.5,53.5,56.599998,59.599998,62.700001,65.699997,68.800003,71.800003,74.900002,77.900002,81.0,84.0,87.099998,90.099998,93.199997,96.199997,99.300003,102.300003,105.300003,108.400002,111.400002,114.5,117.5,120.599998,123.599998,126.699997,129.699997,132.800003,135.800003,138.899994,141.899994,145.0,148.0,151.100006,154.100006,157.199997,160.199997,163.300003,166.300003,169.399994,172.399994,175.399994,178.5,181.5,184.600006,187.600006,190.699997,193.699997,196.800003,199.800003,202.899994,205.899994,209.0,212.0,215.100006,218.100006,221.199997,224.199997,227.300003,230.300003,233.399994,236.399994,239.5,242.5,245.600006,248.600006,251.600006,254.699997,257.700012,260.799988,263.799988,266.899994,269.899994,273.0,276.0,279.100006,282.100006,285.200012,288.200012,291.299988,294.299988,297.399994,300.399994,303.5,306.5,309.600006,312.600006,315.700012,318.700012,321.700012,324.799988,327.799988,330.899994,333.899994,337.0,340.0,343.100006,346.100006,349.200012,352.200012,355.299988,358.299988,361.399994,364.399994,367.5,370.5,373.600006,376.600006,379.700012,382.700012,385.799988,388.799988,391.899994,394.899994,397.899994,401.0,404.0,407.100006,410.100006,413.200012,416.200012,419.299988,422.299988,425.399994,428.399994,431.5,434.5,437.600006,440.600006,443.700012,446.700012,449.799988,452.799988,455.899994,458.899994,462.0,465.0,468.0,471.100006,474.100006,477.200012,480.200012,483.299988,486.299988,489.399994,492.399994,495.5,498.5,501.600006,504.600006,507.700012,510.700012,513.799988,516.799988,519.900024,522.900024,526.0,529.0,532.099976,535.099976,538.200012,541.200012,544.200012,547.299988,550.299988,553.400024,556.400024,559.5,562.5,565.599976,568.599976,571.700012,574.700012,577.799988,580.799988,583.900024,586.900024,590.0,593.0,596.099976,599.099976,602.200012,605.200012,608.299988,611.299988,614.299988,617.400024,620.400024,623.5,626.5,629.599976,632.599976,635.700012,638.700012,641.799988,644.799988,647.900024,650.900024,654.0,657.0,660.099976,663.099976,666.200012,669.200012,672.299988,675.299988,678.400024,681.400024,684.5,687.5,690.5,693.599976,696.599976,699.700012,702.700012,705.799988,708.799988,711.900024,714.900024,718.0,721.0,724.099976,727.099976,730.200012,733.200012,736.299988,739.299988,742.400024,745.400024,748.5,751.5,754.599976,757.599976,760.599976,763.700012,766.700012,769.799988,772.799988,775.900024,778.900024,782.0,785.0,788.099976,791.099976,794.200012,797.200012,800.299988,803.299988,806.400024,809.400024,812.5,815.5,818.599976,821.599976,824.700012,827.700012,830.799988,833.799988,836.799988,839.900024,842.900024,846.0,849.0,852.099976,855.099976,858.200012,861.200012,864.299988,867.299988,870.400024,873.400024,876.5,879.5,882.599976,885.599976,888.700012,891.700012,894.799988,897.799988,900.900024,903.900024,906.900024,910.0,913.0,916.099976,919.099976,922.200012,925.200012,928.299988,931.299988,934.400024,937.400024,940.5,943.5,946.599976,949.599976,952.700012,955.700012,958.799988,961.799988,964.900024,967.900024,971.0,974.0,977.099976,980.099976,983.099976,986.200012,989.200012,992.299988,995.299988,998.400024,1001.400024,1004.5,1007.5,1010.599976,1013.599976,1016.700012,1019.700012,1022.799988,1025.800049,102 ...
