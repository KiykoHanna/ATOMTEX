# %% [markdown]
# import libraries

# %%
import os
from turtle import color
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from turtle import color
import seaborn as sns
from sklearn.linear_model import LinearRegression
from pathlib import Path
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %% [markdown]
# # Read the file with database. The file is readen from the githab.

# %%
# read the file with database
url =' https://raw.githubusercontent.com/KiykoHanna/ATOMTEX/main/1315_database.csv'
db = pd.read_csv(url)
db.columns = ['name',
              'nuclid',
              'time',
              'serial_number',
              'geometry',
              'weight',
              'date',
              'sp_beta',
              'Energy',
              'sp_gamma',
              'R_cal',
              'comments'
              ]

# %%
# convert some columns from string to list
def convert_to_list(a_str):
    return [float(i) for i in a_str[1:-1].split(', ')]

list_of_str = ['Energy', 'R_cal', 'sp_gamma', 'sp_beta']
for i in list_of_str:
    db[i] = db[i].apply(convert_to_list)

# %%
db['time'][0]
# Out:
# 10800.0

# %%
# create function for select and show

# function for searching spectrs including a_sytring in the name
def select_spectr(data, a_str, col_name='name'):
    a = data[col_name]
    b = [i if a_str in str(i) else '---' for i in a]
    data = data.loc[data[col_name].isin(b)]
    return data

# function for showing spectrs
def show_comp_spectr(data):
    fig = make_subplots(rows=2, cols=1)
    color_continuous_scale = ["black", "orange", "red", "green", "blue", "purple", 'turquoise', 'violet', 'wheat', 'yellow', 'yellowgreen']
    for j, i in enumerate(data.index):
        y_gamma = data['sp_gamma'][i] / data['time'][i]
        fig.add_trace(
            go.Scatter(x= data['Energy'][i],
                        y= y_gamma,
                        mode="markers",
                        marker=dict(size=3, color= color_continuous_scale[j % len(color_continuous_scale)]),
                        name=data['name'][i] +'gamma'),
            row=1, col=1,

        )

    for j, i in enumerate(data.index):
        y_beta = data['sp_beta'][i] / data['time'][i]
        fig.add_trace(
            go.Scatter(x=data['Energy'][i],
                        y=y_beta,
                        mode="markers",
                        marker=dict(size=3, color= color_continuous_scale[j % len(color_continuous_scale)]),
                        name=data['name'][i] + 'beta'),
            row=2, col=1
        )

    fig.update_layout(height=600, width=1000, title_text="Spectrs")
    fig.show()

# function for normalizing spectrs hight of peak of total absorption

# %%
# select file to show
data = pd.DataFrame()

search = '5177'
col_for_search = 'serial_number'
data = select_spectr(db, search, col_name= col_for_search)

search = 'С'
col_for_search = 'name'
data = select_spectr(data, search, col_name= col_for_search)



print(data.name)
'total number of mathing spectr:', len(data)
# Out:
# 341                       5С0_0667.5177
# 342                       5С0_0665.5177
# 343                   5С0_0665 0.1.5177
# 344                       5С0_0664.5177
# 345                       5С0_0663.5177
# 360               3С0_2128 на держ.5177
# 361              3С0_2128 без держ.5177
# 362               3С0_2127 на держ.5177
# 363              3С0_2127 без держ.5177
# 364               3С0_2126 на держ.5177
# 365              3С0_2126 без держ.5177
# 414              1С0_2125 без держ.5177
# 415     1С0_2125 без держ 0,5.5177.5177
# 416     1С0_2125 без держ 0,2.5177.5177
# 417     1С0_2125 без держ 0,1.5177.5177
# 418    1С0_2125 без держ 0,03.5177.5177
# 419              1С0_2124 без держ.5177
# Name: name, dtype: object
# ('total number of mathing spectr:', 17)

# %%
n_spectr = [88, 344, 363, 415]

data_aa = db.iloc[n_spectr]
show_comp_spectr(data_aa)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bd8baa9c-5401-4b35-947e-f3abbe0a29c5" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd8baa9c-5401-4b35-947e-f3abbe0a29c5")) {                    Plotly.newPlot(                        "bd8baa9c-5401-4b35-947e-f3abbe0a29c5",                        [{"marker":{"color":"black","size":3},"mode":"markers","name":"SrM10.5177.5177gamma","x":[0.0,0.0,0.0,2.4,5.4,8.4,11.5,14.5,17.6,20.6,23.700001,26.700001,29.700001,32.799999,35.799999,38.900002,41.900002,44.900002,48.0,51.0,54.099998,57.099998,60.099998,63.200001,66.199997,69.300003,72.300003,75.300003,78.400002,81.400002,84.5,87.5,90.5,93.599998,96.599998,99.699997,102.699997,105.699997,108.800003,111.800003,114.900002,117.900002,120.900002,124.0,127.0,130.100006,133.100006,136.100006,139.199997,142.199997,145.300003,148.300003,151.300003,154.399994,157.399994,160.5,163.5,166.5,169.600006,172.600006,175.699997,178.699997,181.800003,184.800003,187.800003,190.899994,193.899994,197.0,200.0,203.0,206.100006,209.100006,212.199997,215.199997,218.199997,221.300003,224.300003,227.399994,230.399994,233.399994,236.5,239.5,242.600006,245.600006,248.600006,251.699997,254.699997,257.799988,260.799988,263.799988,266.899994,269.899994,273.0,276.0,279.0,282.100006,285.100006,288.200012,291.200012,294.200012,297.299988,300.299988,303.399994,306.399994,309.399994,312.5,315.5,318.600006,321.600006,324.700012,327.700012,330.700012,333.799988,336.799988,339.899994,342.899994,345.899994,349.0,352.0,355.100006,358.100006,361.100006,364.200012,367.200012,370.299988,373.299988,376.299988,379.399994,382.399994,385.5,388.5,391.5,394.600006,397.600006,400.700012,403.700012,406.700012,409.799988,412.799988,415.899994,418.899994,421.899994,425.0,428.0,431.100006,434.100006,437.100006,440.200012,443.200012,446.299988,449.299988,452.299988,455.399994,458.399994,461.5,464.5,467.5,470.600006,473.600006,476.700012,479.700012,482.799988,485.799988,488.799988,491.899994,494.899994,498.0,501.0,504.0,507.100006,510.100006,513.200012,516.200012,519.200012,522.299988,525.299988,528.400024,531.400024,534.400024,537.5,540.5,543.599976,546.599976,549.599976,552.700012,555.700012,558.799988,561.799988,564.799988,567.900024,570.900024,574.0,577.0,580.0,583.099976,586.099976,589.200012,592.200012,595.200012,598.299988,601.299988,604.400024,607.400024,610.400024,613.5,616.5,619.599976,622.599976,625.599976,628.700012,631.700012,634.799988,637.799988,640.900024,643.900024,646.900024,650.0,653.0,656.099976,659.099976,662.099976,665.200012,668.200012,671.299988,674.299988,677.299988,680.400024,683.400024,686.5,689.5,692.5,695.599976,698.599976,701.700012,704.700012,707.700012,710.799988,713.799988,716.900024,719.900024,722.900024,726.0,729.0,732.099976,735.099976,738.099976,741.200012,744.200012,747.299988,750.299988,753.299988,756.400024,759.400024,762.5,765.5,768.5,771.599976,774.599976,777.700012,780.700012,783.700012,786.799988,789.799988,792.900024,795.900024,799.0,802.0,805.0,808.099976,811.099976,814.200012,817.200012,820.200012,823.299988,826.299988,829.400024,832.400024,835.400024,838.5,841.5,844.599976,847.599976,850.599976,853.700012,856.700012,859.799988,862.799988,865.799988,868.900024,871.900024,875.0,878.0,881.0,884.099976,887.099976,890.200012,893.200012,896.200012,899.299988,902.299988,905.400024,908.400024,911.400024,914.5,917.5,920.599976,923.599976,926.599976,929.700012,932.700012,935.799988,938.799988,941.799988,944.900024,947.900024,951.0,954.0,957.099976,960.099976,963.099976,966.200012,969.200012,972.299988,975.299988,978.299988,981.400024,984.400024,987.5,990.5,993.5,996.599976,999.599976,1002.700012,1005.700012,1008.700012,1011.799988,1014.799988,1017.900024,1020.900024,1023.900024,1027.0,1030.0, ...
